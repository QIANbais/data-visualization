# %% [markdown]
# ### Import Labraries

# %%
import os
import json
import folium
import pandas as pd
import numpy as np

os.chdir('C:/Users/97905/Desktop/Spring 2020/ISM6419-Data Visualization/Week 8/in class 2')
os.getcwd()

country_geo = 'world-countries.json'

# %% [markdown]
# ### Import csv into Pandas DataFrame

# %%
df = pd.read_csv("04-01-2020.csv")
df['Confirmed']=df.Confirmed.astype(float)
df.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region     Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  4/1/2020 21:58
# 1  22001.0     Acadia       Louisiana             US  4/1/2020 21:58
# 2  51001.0   Accomack        Virginia             US  4/1/2020 21:58
# 3  16001.0        Ada           Idaho             US  4/1/2020 21:58
# 4  19001.0      Adair            Iowa             US  4/1/2020 21:58
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       0
# 1  30.295065  -92.414197         47       1          0       0
# 2  37.767072  -75.632346          7       0          0       0
# 3  43.452658 -116.241552        195       3          0       0
# 4  41.330756  -94.471059          1       0          0       0
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# ...

# %% [markdown]
# ### Creating the Folium interactive map

# %%
world_map = folium.Map(location=[11,0], tiles="cartodbpositron", zoom_start=2, max_zoom = 6, min_zoom = 2)
# iterate over all the rows of confirmed_df to get the lat/long
for i in range(0,len(df)):
    folium.Circle(
        location=[df.iloc[i]['Lat'], df.iloc[i]['Long_']],
        fill=True,
        radius=(int((np.log(df.iloc[i,7]+1.00001)))+0.2)*30000,
        color='red',
        fill_color='red',
    ).add_to(world_map)
    
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### the visualization above display the confirmed cases across world on 04/01/202
